# %% [markdown]
# # Developing a Research Question and Creating a Personal Code Book

# %% [markdown]
# ##### INTRODUCTION

# %% [markdown]
# I have selected for my analysis the NESARC codebook a survey designed to determine the magnitude of alcohol use and psychiatric disorders in the U.S. population. It is a representative sample of the non-institutionalized population 18 years and older. I found deeply interesting the association between an adopted child and how he's lifes going, including any trouble that she/he can be involved. Over the last years adoption has become a less secretive and increasingly valid way to build a family, resulting in the increased prevalence of adoptive families within the U.S, but we need to know how this childs and this family ends up.

# %% [markdown]
# ##### QUESTION.

# %% [markdown]
# has been adopted before the 18 years old could be generate any disorder or, influence the current situation?

# %% [markdown]
# ##### HYPOTHESIS

# %% [markdown]
# According to the information in my posses, whe can though that the relathionship between the young childs and the present situation in not the best one, talking about the school, work present. On the other hand we can suppouse that the relationship between a child and personality disorder or antisocial personality disorder could be not so deep.

# %% [markdown]
# ##### NESARC Codebook Sections and Variables

# %% [markdown]
# By looking on the NESARC pdf i decide to select this varibles:
# ![selezione.png](attachment:selezione.png)

# %% [markdown]
# ![alchool.png](attachment:alchool.png)
# ![dependence.png](attachment:dependence.png)
# ![other.png](attachment:other.png)

# %% [markdown]
# ##### REVIEW

# %% [markdown]
# I haven't found articles just talking about the relationship between adopted childs and antisocial disorder itself ,some articles describes the relathionship child-parents(example: maltreatment)  and disorders so this could be a nice topic to profundize, because the relation whit the parents might affect the behavior.Talking about the other relathonship, child and occupation like working or studying, we need to taking into account more variables factors such as any abuse, disorder or dependece which might affect the situation of the child.I have taking into account the abuse of drugs for the study.This is the result of one of the study about this topic from the national institute of health:
#
# The data come from the National Epidemiologic Survey on Alcohol and Related Conditions (NESARC). The main outcome measure was the prevalence of lifetime SUDs in adopted (n = 378) and nonadopted adults (n = 42503). Adoptees and nonadoptees were compared to estimate the odds of lifetime SUDs using logistic regression analysis. Adoptees had higher prevalence rates of lifetime SUDs than nonadoptees. Overall, adoptees had a 1.87-fold increase (adjusted odds ratio [AOR] 1.87, 95% CI 1.51–2.31) in the odds of any lifetime SUD compared to nonadoptees. For each SUD, adoptees had higher odds for alcohol abuse/dependence (AOR 1.84), nicotine dependence (AOR 1.78), cannabis abuse/dependence (AOR 1.77), cocaine abuse/dependence (AOR 2.54), amphetamine abuse/dependence (AOR 3.14), hallucinogen abuse/dependence (AOR 2.85), opioid abuse/dependence (AOR 2.21), and other drug abuse/dependence (AOR 2.87) compared to nonadoptees

# %% [markdown]
# ##### REFERENCES

# %% [markdown]
# https://psycnet.apa.org/record/2010-02774-003?doi=1
#
# https://pubmed.ncbi.nlm.nih.gov/21038930/
#
# https://link.springer.com/article/10.1007/s10802-011-9505-7
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3499473/
