# %% [markdown]
# # Making Data Management Decisions

# %% [markdown]
# ##### Preview

# %% [markdown]
# In this assignment you will find three data managed variables, provided from NESARC codebook, as frequency distributions. First one is the variable [S1Q2K]BIOLOGICAL OR ADOPTIVE PARENT DIE BEFORE RESPONDENT WAS 18 and i've deleted the row unknow,and set to nan the row BL.Then my second variable is [CONSUMER] indicates wheter a person is actually a aalchol drinker or not.the third variable is [S4AQ20B] and is talking about the necessity of drink alchool to feel better.
# The last variable ['S2AQ8D'] is related about the quantity of alcohol the past in the past 12 months.I'll start separete the youngests of 18 and then divide it in two subsets.

# %%
import pandas 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pandas.read_csv('nesarc.csv')

df.head()
# Out:
#    Unnamed: 0  ETHRACE2A ETOTLCA2  IDNUM    PSU  STRATUM      WEIGHT  CDAY  \
# 0           0          5               1   4007      403 3928.613505    14
# 1           1          5   0.0014      2   6045      604 3638.691845    12
# 2           2          5               3  12042     1218 5779.032025    23
# 3           3          5               4  17099     1704 1071.754303     9
# 4           4          2               5  17099     1704 4986.952377    18
#
#    CMON  CYEAR  ...  SOLP12ABDEP  HAL12ABDEP  HALP12ABDEP  MAR12ABDEP  \
# 0     8   2001  ...     0.000000    0.000000     0.000000    0.000000
# 1     1   2002  ...     0.000000    0.000000     0.000000    0.000000
# 2    11   2001  ...     0.000000    0.000000     0.000000    0.000000
# 3     9   2001  ...     0.000000    0.000000     0.000000    0.000000
# 4    10   2001  ...     0.000000    0.000000     0.000000    0.000000
#
#    MARP12ABDEP  HER12ABDEP  HERP12ABDEP  OTHB12ABDEP  OTHBP12ABDEP  NDSymptoms
# 0     0.000000    0.000000     0.000000     0.000000      0.000000         nan
# 1     0.000000    0.000000     0.000000     0.000000      0.000000         nan
# 2     0.000000    0.000000     0.000000     0.000000      0.000000         nan
# 3     0.000000    0.000000     0.000000     0.000000      0.000000         nan
# 4     0.000000    0.000000     0.000000     0.000000      0.000000         nan
#
# [5 rows x 3010 columns]

# %%
pandas.set_option('display.float_format' , lambda x:'%f'%x)
df.describe()
# Out:
#        Unnamed: 0   ETHRACE2A       IDNUM          PSU     STRATUM  \
# count 8185.000000 8185.000000 8185.000000  8185.000000 8185.000000
# mean  4092.000000    2.040073 4093.000000 29636.264997 2958.929016
# std   2362.950310    1.538717 2362.950310 15772.518085 1568.717690
# min      0.000000    1.000000    1.000000  1001.000000  101.000000
# 25%   2046.000000    1.000000 2047.000000 13097.000000 1308.000000
# 50%   4092.000000    1.000000 4093.000000 31098.000000 3109.000000
# 75%   6138.000000    2.000000 6139.000000 42095.000000 4216.000000
# max   8184.000000    5.000000 8185.000000 56017.000000 5605.000000
#
#             WEIGHT        CDAY        CMON       CYEAR      REGION  ...  \
# count  8185.000000 8185.000000 8185.000000 8185.000000 8185.000000  ...
# mean   4942.638069   16.225779    8.713256 2001.129872    2.639829  ...
# std    3347.099407    8.738690    2.993762    0.336183    0.891212  ...
# min     398.855701    1.000000    1.000000 2001.000000    1.000000  ...
# 25%    2717.532245    9.000000    8.000000 2001.000000    2.000000  ...
# 50%    3827.362169   16.000000    9.000000 2001.000000    3.000000  ...
# 75%    6986.299036   24.000000   11.000000 2001.000000    3.000000  ...
# max   37648.529080   31.000000   12.000000 2002.000000    4.000000  ...
#
#        SOLP12ABDEP  HAL12ABDEP  HALP12ABDEP  MAR12ABDEP  MARP12ABDEP  \
# count  8184.000000 8184.000000  8184.000000 8184.000000  8184.000000
# mean      0.004765    0.000611     0.017351    0.015152     0.084800
# std       0.088998    0.024711     0.164538    0.169147     0.357382
# min       0.000000    0.000000     0.000000    0.000000     0.000000
# 25%       0.000000    0.000000     0.000000    0.000000     0.000000
# 50%       0.000000    0.000000     0.000000    0.000000     0.000000
# 75%       0.000000    0.000000     0.000000    0.000000     0.000000
# max       3.000000    1.000000     3.000000    3.000000     3.000000
#
#        HER12ABDEP  HERP12ABDEP  OTHB12ABDEP  OTHBP12ABDEP  NDSymptoms
# count 8184.000000  8184.000000  8184.000000   8184.000000  261.000000
# mean     0.000489     0.005254     0.000000      0.000489    2.421456
# std      0.034954     0.115294     0.000000      0.027074    1.786315
# min      0.000000     0.000000     0.000000      0.000000    0.000000
# 25%      0.000000     0.000000     0.000000      0.000000    1.000000
# 50%      0.000000     0.000000     0.000000      0.000000    2.000000
# 75%      0.000000     0.000000     0.000000      0.000000    4.000000
# max      3.000000     3.000000     0.000000      2.000000    6.000000
#
# [8 rows x 682 columns]

# %%
df = df.replace(r'^\s*$', np.NaN, regex=True)

# %%
df1=df[(df['AGE']==18)]
df1
# Out:
#       Unnamed: 0  ETHRACE2A ETOTLCA2  IDNUM    PSU  STRATUM      WEIGHT  CDAY  \
# 3              3          5      NaN      4  17099     1704 1071.754303     9
# 9              9          5   0.1565     10   4013      404 3008.554718    16
# 36            36          5      NaN     37  36094     3616 2292.549993    17
# 153          153          4      NaN    154   6098      624 6853.268126    28
# 156          156          5      NaN    157  36094     3616 1586.297176    29
# ...          ...        ...      ...    ...    ...      ...         ...   ...
# 7914        7914          1   0.6544   7915  39091     3913 7850.316750    30
# 7950        7950          3   0.0025   7951  34011     3407 9030.603521    28
# 8032        8032          1      NaN   8033  13097     1306 8657.814391    17
# 8086        8086          1   0.0744   8087  46001     4601 3791.054404    30
# 8138        8138          1      NaN   8139  31032     3106 6809.443772    26
#
#       CMON  CYEAR  ...  SOLP12ABDEP  HAL12ABDEP  HALP12ABDEP  MAR12ABDEP  \
# 3        9   2001  ...     0.000000    0.000000     0.000000    0.000000
# 9        8   2001  ...     0.000000    0.000000     0.000000    1.000000
# 36       1   2002  ...     0.000000    0.000000     0.000000    0.000000
# 153      9   2001  ...     0.000000    0.000000     0.000000    0.000000
# 156      9   2001  ...     0.000000    0.000000     0.000000    0.000000
# ...    ...    ...  ...          ...         ...          ...         ...
# 7914    12   2001  ...     0.000000    0.000000     0.000000    0.000000
# 7950     8   2001  ...     0.000000    0.000000     0.000000    0.000000
# 8032    10   2001  ...     0.000000    0.000000     0.000000    0.000000
# 8086     8   2001  ...     0.000000    0.000000     0.000000    0.000000
# 8138     9   2001  ...     0.000000    0.000000     0.000000    0.000000
#
#       MARP12ABDEP  HER12ABDEP  HERP12ABDEP  OTHB12ABDEP  OTHBP12ABDEP  \
# 3        0.000000    0.000000     0.000000     0.000000      0.000000
# 9        0.000000    0.000000     0.000000     0.000000      0.000000
# 36       0.000000    0.000000     0.000000     0.000000      0.000000
# 153      0.000000    0.000000     0.000000     0.000000      0.000000
# 156      0.000000    0.000000     0.000000     0.000000      0.000000
# ...           ...         ...          ...          ...           ...
# 7914     0.000000    0.000000     0.000000     0.000000      0.000000
# 7950     0.000000    0.000000     0.000000     0.000000      0.000000
# 8032     0.000000    0.000000     0.000000     0.000000      0.000000
# 8086     0.000000    0.000000     0.000000     0.000000      0.000000
# 8138     0.000000    0.000000     0.000000     0.000000      0.000000
#
#       NDSymptoms
# 3            nan
# 9            nan
# 36           nan
# 153          nan
# 156          nan
# ...          ...
# 7914    1.000000
# 7950         nan
# 8032         nan
# 8086    0.000000
# 8138    4.000000
#
# [128 rows x 3010 columns]

# %%
df1.dtypes
# Out:
# Unnamed: 0        int64
# ETHRACE2A         int64
# ETOTLCA2         object
# IDNUM             int64
# PSU               int64
#                  ...
# HER12ABDEP      float64
# HERP12ABDEP     float64
# OTHB12ABDEP     float64
# OTHBP12ABDEP    float64
# NDSymptoms      float64
# Length: 3010, dtype: object

# %%
#DRANK ALCOHOL TO IMPROVE MOOD IN LAST 12 MONTHS S4A
#CONSUMER DRINKING STATUS consumer
df1=df1[['S1Q2K','SEX','S4AQ20B','CONSUMER','S2AQ8D','S10Q1B3']]  
 
df1
# Out:
#      S1Q2K  SEX S4AQ20B  CONSUMER S2AQ8D  S10Q1B3
# 3        2    1     NaN         2    NaN 2.000000
# 9        2    2     NaN         1     10 2.000000
# 36       2    1     NaN         3    NaN 2.000000
# 153      2    2     NaN         3    NaN 2.000000
# 156      2    1     NaN         3    NaN 2.000000
# ...    ...  ...     ...       ...    ...      ...
# 7914     2    2     NaN         1      9 2.000000
# 7950     2    1     NaN         1     10 2.000000
# 8032     2    1     NaN         3    NaN 2.000000
# 8086     2    1     NaN         1      9 2.000000
# 8138     2    1     NaN         3    NaN 2.000000
#
# [128 rows x 6 columns]

# %%
#unique values
df1['S1Q2K'].unique()
# Out:
# array(['2', nan, '1', '9'], dtype=object)

# %%
#recode some columns with different name variables
df1=df1.rename(columns={'S4AQ20B': 'ALC4MOOD', 'S2AQ8D': 'ALCL_12MO','S10Q1B3':'TROUBLS'})

# %%
#remap the indicators of ALCL_12MO QUANTITY
df1["ALCL_12MO"].replace({"10": "4", "9": "4",'8':'4','7':'4','6':'3','5':'3','4':'2','3':'2','2':'1','1':'1'}, inplace=True)

# %%
df1['S1Q2K'] = pandas.to_numeric(df1['S1Q2K'], errors='coerce')
df1 = df1.dropna(subset=['S1Q2K'])
df1['S1Q2K'] = df1['S1Q2K'].astype(int)
df1['ALC4MOOD'] = df1['ALC4MOOD'].astype(float)
df1['ALCL_12MO'] = df1['ALCL_12MO'].astype(float)

# %%
df1['S1Q2K'].replace([9], np.nan, inplace=True)
df1['S1Q2K'].replace([0.000000], np.nan, inplace=True)
df1['ALCL_12MO'].replace([99],np.nan, inplace=True)
df1['ALC4MOOD'].replace([0.000000], np.nan, inplace=True)
df1['TROUBLS'].replace([9.000000], np.nan, inplace=True)

# %%
#dead parewnts before 18
subset1 = df1[(df1['S1Q2K'] ==1)]
subset1
# Out:
#         S1Q2K  SEX  ALC4MOOD  CONSUMER  ALCL_12MO  TROUBLS
# 945  1.000000    1  2.000000         1   4.000000 2.000000
# 3540 1.000000    2       nan         3        nan 2.000000
# 4747 1.000000    2       nan         1   4.000000      nan
# 4867 1.000000    2       nan         2        nan 2.000000
# 5629 1.000000    2       nan         2        nan 2.000000
# 6560 1.000000    1  2.000000         1   4.000000 1.000000
# 7193 1.000000    1       nan         3        nan 2.000000

# %%
#no dead parents before 18
subset2 = df1[(df1['S1Q2K'] ==2)]
subset2
# Out:
#         S1Q2K  SEX  ALC4MOOD  CONSUMER  ALCL_12MO  TROUBLS
# 3    2.000000    1       nan         2        nan 2.000000
# 9    2.000000    2       nan         1   4.000000 2.000000
# 36   2.000000    1       nan         3        nan 2.000000
# 153  2.000000    2       nan         3        nan 2.000000
# 156  2.000000    1       nan         3        nan 2.000000
# ...       ...  ...       ...       ...        ...      ...
# 7914 2.000000    2       nan         1   4.000000 2.000000
# 7950 2.000000    1       nan         1   4.000000 2.000000
# 8032 2.000000    1       nan         3        nan 2.000000
# 8086 2.000000    1       nan         1   4.000000 2.000000
# 8138 2.000000    1       nan         3        nan 2.000000
#
# [116 rows x 6 columns]

# %% [markdown]
# EVER TROUBLE YOU OR CAUSE PROBLEMS AT WORK/SCHOOL OR WITH FAMILY/OTHER PEOPLE?

# %%
df1['TROUBLS'].value_counts(dropna=True)
# Out:
# 2.000000    111
# 1.000000      6
# Name: TROUBLS, dtype: int64

# %% [markdown]
# DID BIOLOGICAL OR ADOPTIVE PARENT DIE BEFORE RESPONDENT WAS 18?

# %%
# dead before 18 values
df1['S1Q2K'].value_counts(dropna=True)
# Out:
# 2.000000    116
# 1.000000      7
# Name: S1Q2K, dtype: int64

# %%
deads_prc = df1.groupby('S1Q2K').size() * 100 / len(df1)   #percentages of parents died before respondent has 18
deads_prc
# Out:
# S1Q2K
# 1.000000    5.645161
# 2.000000   93.548387
# dtype: float64

# %% [markdown]
# DRANK ALCOHOL TO IMPROVE MOOD IN LAST 12 MONTHS?

# %%
# alchool to improve mood users
df1['ALC4MOOD'].value_counts(dropna=True)#102 Nan values deleted
# Out:
# 2.000000    19
# 1.000000     3
# Name: ALC4MOOD, dtype: int64

# %%
impr_mood_per=df1.groupby('ALC4MOOD').size() * 100 / len(df1)
impr_mood_per
# Out:
# ALC4MOOD
# 1.000000    2.419355
# 2.000000   15.322581
# dtype: float64

# %% [markdown]
# DRINKING STATUS?

# %%
# total alohol drinkers under 18 years old
df1['CONSUMER'].value_counts(dropna=True)
# Out:
# 1    59
# 3    55
# 2    10
# Name: CONSUMER, dtype: int64

# %%
consumr_per=df1.groupby('CONSUMER').size() * 100 / len(df1)
consumr_per
# Out:
# CONSUMER
# 1   47.580645
# 2    8.064516
# 3   44.354839
# dtype: float64

# %% [markdown]
# HOW OFTEN DRANK LARGEST NUMBER OF DRINKS OF ANY ALCOHOL IN LAST 12 MONTHS?

# %%
#quantity of alchol in a timeframe
df1['ALCL_12MO'].value_counts(dropna=True) #69 Nan values deleted
# Out:
# 4.000000    48
# 3.000000     8
# 2.000000     2
# Name: ALCL_12MO, dtype: int64

# %%
df1.groupby('ALCL_12MO').size() * 100 / len(df1)
# Out:
# ALCL_12MO
# 2.000000    1.612903
# 3.000000    6.451613
# 4.000000   38.709677
# dtype: float64

# %% [markdown]
# Firstly, a new 2 variables called ‘subset1’ and 'subset2'  was necessary to be created in order to divide the partecipants, then i dropped Na and unkown information so this could cause some different resulte in this project, In addition i changed the variable name['S4AQ20B'] in ['ALC4MOOD'] and ['S2AQ8D'] in ['ALCL_12MO'] finally i I have related the subset 1(parents died before child has 18) with 'current drinkers' variable and we can ntice that (in a really small quantity)  the death of parents before 18 can affect the child and he could be a drinker.On the other side children in the subset two we can notice a high percentage of lifetime absatiner and current drinkers.

# %%
subset2['ALC4MOOD'] = subset2['ALC4MOOD'].astype(float)
subset2['ALCL_12MO'] = subset2['ALCL_12MO'].astype(float)

# %%
subset1['ALC4MOOD'] = subset1['ALC4MOOD'].astype(float)
subset1['ALCL_12MO'] = subset1['ALCL_12MO'].astype(float)

# %%
#def a functioninorder to 
def ALCOHOLDIST (row):
    if row['ALC4MOOD'] ==1 :
        return 5
    if row['ALCL_12MO'] == 1 :
        return 1
    if row['ALCL_12MO'] == 2 :
        return 2
    if row['ALCL_12MO'] == 3 :
        return 3
    if row['ALCL_12MO'] == 4 :
        return 4

# %%
#relation between  childresns with dead parents before 18 and if they are current alcohol drinkers
relation1= df1.groupby('TROUBLS').size()
relation1
# Out:
# TROUBLS
# 1.000000      6
# 2.000000    111
# dtype: int64

# %%
#percentage of alchool consumer with dad parents
relation1p=subset1.groupby('TROUBLS').size() * 100 / len(subset1)
relation1p
# Out:
# TROUBLS
# 1.000000   14.285714
# 2.000000   71.428571
# dtype: float64

# %%
#relation between  childresns with no dead parents before 18 and if they are current alcohol drinkers
relation2=subset2.groupby('CONSUMER').size()
relation2
# Out:
# CONSUMER
# 1    55
# 2     8
# 3    53
# dtype: int64

# %%
#percentage of alchool consumer with no dead parents
relation2p=subset2.groupby('CONSUMER').size() * 100 / len(subset2)
relation2p
# Out:
# CONSUMER
# 1   47.413793
# 2    6.896552
# 3   45.689655
# dtype: float64

# %%
subset2.dtypes
# Out:
# S1Q2K        float64
# SEX            int64
# ALC4MOOD     float64
# CONSUMER       int64
# ALCL_12MO    float64
# TROUBLS      float64
# dtype: object

# %%
subset1['ALCOHOLDIST'] = subset1.apply (lambda row: ALCOHOLDIST (row), axis=1)
subsetfin1 =subset1[['S1Q2K','ALCL_12MO', 'ALC4MOOD','ALCOHOLDIST']].copy()
subsetfin1.style.set_precision(0)
# Out:
# <style  type="text/css" >
# </style><table id="T_c1a689ee_9e33_11ec_9303_0242ac110037" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >S1Q2K</th>        <th class="col_heading level0 col1" >ALCL_12MO</th>        <th class="col_heading level0 col2" >ALC4MOOD</th>        <th class="col_heading level0 col3" >ALCOHOLDIST</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1a689ee_9e33_11ec_9303_0242ac110037level0_row0" class="row_heading level0 row0" >945</th>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row0_col1" class="data row0 col1" >4</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row0_col2" class="data row0 col2" >2</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row0_col3" class="data row0 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a689ee_9e33_11ec_9303_0242ac110037level0_row1" class="row_heading level0 row1" >3540</th>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row1_col3" class="data row1 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a689ee_9e33_11ec_9303_0242ac110037level0_row2" class="row_heading level0 row2" >4747</th>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row2_col1" class="data row2 col1" >4</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row2_col3" class="data row2 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a689ee_9e33_11ec_9303_0242ac110037level0_row3" class="row_heading level0 row3" >4867</th>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row3_col3" class="data row3 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a689ee_9e33_11ec_9303_0242ac110037level0_row4" class="row_heading level0 row4" >5629</th>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row4_col1" class="data row4 col1" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row4_col2" class="data row4 col2" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row4_col3" class="data row4 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a689ee_9e33_11ec_9303_0242ac110037level0_row5" class="row_heading level0 row5" >6560</th>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row5_col0" class="data row5 col0" >1</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row5_col2" class="data row5 col2" >2</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row5_col3" class="data row5 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a689ee_9e33_11ec_9303_0242ac110037level0_row6" class="row_heading level0 row6" >7193</th>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row6_col0" class="data row6 col0" >1</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row6_col1" class="data row6 col1" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row6_col2" class="data row6 col2" >nan</td>
#                         <td id="T_c1a689ee_9e33_11ec_9303_0242ac110037row6_col3" class="data row6 col3" >nan</td>
#             </tr>
#     </tbody></table>

# %%
subset2['ALCOHOLDIST'] = subset2.apply (lambda row: ALCOHOLDIST (row), axis=1)
subsetfin2 =subset2[['S1Q2K','ALCL_12MO', 'ALC4MOOD','ALCOHOLDIST']].copy()
subsetfin2.style.set_precision(0)
# Out:
# <style  type="text/css" >
# </style><table id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >S1Q2K</th>        <th class="col_heading level0 col1" >ALCL_12MO</th>        <th class="col_heading level0 col2" >ALC4MOOD</th>        <th class="col_heading level0 col3" >ALCOHOLDIST</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row0_col0" class="data row0 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row0_col3" class="data row0 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row1" class="row_heading level0 row1" >9</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row1_col3" class="data row1 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row2" class="row_heading level0 row2" >36</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row2_col3" class="data row2 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row3" class="row_heading level0 row3" >153</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row3_col0" class="data row3 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row3_col3" class="data row3 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row4" class="row_heading level0 row4" >156</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row4_col1" class="data row4 col1" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row4_col2" class="data row4 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row4_col3" class="data row4 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row5" class="row_heading level0 row5" >187</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row5_col0" class="data row5 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row5_col1" class="data row5 col1" >4</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row5_col2" class="data row5 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row5_col3" class="data row5 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row6" class="row_heading level0 row6" >210</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row6_col0" class="data row6 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row6_col1" class="data row6 col1" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row6_col2" class="data row6 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row6_col3" class="data row6 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row7" class="row_heading level0 row7" >357</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row7_col0" class="data row7 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row7_col1" class="data row7 col1" >4</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row7_col2" class="data row7 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row7_col3" class="data row7 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row8" class="row_heading level0 row8" >365</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row8_col0" class="data row8 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row8_col1" class="data row8 col1" >4</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row8_col2" class="data row8 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row8_col3" class="data row8 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row9" class="row_heading level0 row9" >398</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row9_col0" class="data row9 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row9_col1" class="data row9 col1" >4</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row9_col2" class="data row9 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row9_col3" class="data row9 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row10" class="row_heading level0 row10" >418</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row10_col0" class="data row10 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row10_col1" class="data row10 col1" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row10_col2" class="data row10 col2" >nan</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row10_col3" class="data row10 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row11" class="row_heading level0 row11" >445</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row11_col0" class="data row11 col0" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row11_col1" class="data row11 col1" >4</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row11_col2" class="data row11 col2" >2</td>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row11_col3" class="data row11 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037level0_row12" class="row_heading level0 row12" >450</th>
#                         <td id="T_c1a8d3d4_9e33_11ec_9303_0242ac110037row12_col0" class="data row

# %%
finl_prcntg1=subsetfin1.groupby('ALCOHOLDIST').size() * 100 / len(subset1)
finl_prcntg1
# Out:
# ALCOHOLDIST
# 4.000000   42.857143
# dtype: float64

# %%
finl_prcntg2=subsetfin2.groupby('ALCOHOLDIST').size() * 100 / len(subset2)
finl_prcntg2
# Out:
# ALCOHOLDIST
# 2.000000    1.724138
# 3.000000    6.896552
# 4.000000   35.344828
# 5.000000    2.586207
# dtype: float64

# %%
subset3=df1[['S1Q2K','ALCL_12MO','SEX','CONSUMER','ALC4MOOD','TROUBLS']].copy()
subset3
# Out:
#         S1Q2K  ALCL_12MO  SEX  CONSUMER  ALC4MOOD  TROUBLS
# 3    2.000000        nan    1         2       nan 2.000000
# 9    2.000000   4.000000    2         1       nan 2.000000
# 36   2.000000        nan    1         3       nan 2.000000
# 153  2.000000        nan    2         3       nan 2.000000
# 156  2.000000        nan    1         3       nan 2.000000
# ...       ...        ...  ...       ...       ...      ...
# 7914 2.000000   4.000000    2         1       nan 2.000000
# 7950 2.000000   4.000000    1         1       nan 2.000000
# 8032 2.000000        nan    1         3       nan 2.000000
# 8086 2.000000   4.000000    1         1       nan 2.000000
# 8138 2.000000        nan    1         3       nan 2.000000
#
# [124 rows x 6 columns]

# %% [markdown]
# ## Exploration Phase

# %%
subset3['TROUBLS'] = subset3['TROUBLS'].astype('category')
subset3['TROUBLS'] = subset3['TROUBLS'].cat.rename_categories(["yes","no"])
sns.countplot(x='S1Q2K', data=subset3)
plt.xlabel('')
plt.title('Troubles at work or school')
plt.show()

# %%
subset3['S1Q2K'] = subset3['S1Q2K'].astype('category')
subset3['S1Q2K'] = subset3['S1Q2K'].cat.rename_categories(["yes","no"])
sns.countplot(x='S1Q2K', data=subset3)
plt.xlabel('deaths')
plt.title('death parent before 18')
plt.show()

# %% [markdown]
# In this graphic we can see the amount of per

# %%
subset3['ALC4MOOD'] = subset3['ALC4MOOD'].astype('category')
subset3['ALC4MOOD'] = subset3['ALC4MOOD'].cat.rename_categories(["yes","no"])
sns.countplot(x='ALC4MOOD', data=subset3)
plt.xlabel('alchool')
plt.title('alcohol to improve mood')
plt.show()

# %% [markdown]
# In this chart above we can check how many people use alcohol to improve their mood.

# %%
subset3['CONSUMER'] = subset3['CONSUMER'].astype('category')
subset3['CONSUMER'] = subset3['CONSUMER'].cat.rename_categories(["current drinker","ex-drinker","lifetime abstainer"])
sns.countplot(x='CONSUMER', data=subset3)
plt.xlabel('alchool consumer')
plt.title('current alchol consumer?')
plt.show()

# %% [markdown]
# In this graphic we can check tha amount of current drinkers or ex-drinkers or either lifetime absteiner

# %%
df1['ALCL_12MO'] = df1['ALCL_12MO'].astype('category')
df1['ALCL_12MO'] = df1['ALCL_12MO'].cat.rename_categories(["2/4 times a week","once a week or less","once a month or less"])
sns.countplot(x='ALCL_12MO', data=df1)
plt.xlabel('alchool quantity')
plt.title('alcohol per time')
plt.show()

# %% [markdown]
# In the bar chart above we can see the relationship between quantity of alchool drunk in the past 12 month by a child with dead parents, and the gender.we can see that people who drank alcohol once a month or less used to be men.

# %%
pandas.get_dummies(subset3, columns = ['TROUBLS'], drop_first =True)
subset3=subset3.rename(columns={'TROUBLS_2.0': 'TROUBLES'})

# %%
df1.info
# Out:
# <bound method DataFrame.info of         S1Q2K  SEX  ALC4MOOD  CONSUMER             ALCL_12MO  TROUBLS
# 3    2.000000    1       nan         2                   NaN 2.000000
# 9    2.000000    2       nan         1  once a month or less 2.000000
# 36   2.000000    1       nan         3                   NaN 2.000000
# 153  2.000000    2       nan         3                   NaN 2.000000
# 156  2.000000    1       nan         3                   NaN 2.000000
# ...       ...  ...       ...       ...                   ...      ...
# 7914 2.000000    2       nan         1  once a month or less 2.000000
# 7950 2.000000    1       nan         1  once a month or less 2.000000
# 8032 2.000000    1       nan         3                   NaN 2.000000
# 8086 2.000000    1       nan         1  once a month or less 2.000000
# 8138 2.000000    1       nan         3                   NaN 2.000000
#
# [124 rows x 6 columns]>

# %%
sns.set_color_codes("pastel")
sns.barplot(x="ALC4MOOD", y="TROUBLS", data=df1 ,palette='deep',
            label="Total", color="b")

# %% [markdown]
# In this second 2d variables is possible to notice that there are no relation between people who's use alchool to improve mood and the variable troubles at work or school. we can see just that people who do not use alcohol to improve mood might be involved in some troubles but just in a real small quantity.

# %%
sns.set_color_codes("pastel")
sns.barplot(x="TROUBLS", y="ALCL_12MO", data=df1 ,palette='deep',
            label="Total", color="b")

# %% [markdown]
# in this case we can notce that is more possibile that who do no used to drink every day but just sometimes could be affected more from the alchool use.

# %% [markdown]
# ##### CONCLUSION

# %% [markdown]
# Finally with all of those observation we can conclude that the new variable ['ALCOHOLDIST'] related with both of the subsets, childrens whose have experienced the death of a family member(parents) ['S1Q2K'] and quantity of alcohol. the 42.8% drank only between 1-6 times during the past 12 months. Now with the other subset n.2 childrens with no death of any family member just 1.7 % drank between 2 and 4 times a week, and 6.8% use to drink between 1 and 3 times a month and the bigger part 35.3% of the partecipants use to drink just between 1 to 11 times a year.No correlation with subset1 and the variable ['ALC4MOOD'] alchool to improve mood, and just a small percentage of 2.5 in the subset2.
# we can also conclude that the relation between the use of alcohol for improve mood['ALCOOL4MOOD'] and get in troubles ['TROUBLS'] at school or at home it's more pronounced for people who use alcohol for fun, and we can appreciate in the last graphic that those who drink less ['ALCL_12MO']  make himself in trouble more quite easily compared to the other 2 groups.['TROUBLS'].

# %% [markdown]
# ##### LIMITATIONS

# %% [markdown]
# we need to take into account that this project has a lot of miss values so this could impact the final result.
